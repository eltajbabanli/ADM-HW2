# %% [markdown]
# # RQ2: What are the time slots with more passengers?

# %% [markdown]
# In the next lines we are going to analyze the datas about the movement of yellow taxis around New York, and in particular we are interested in when New Yorkers take more cabs. To do that we are going to upload our data and count how many passengers there are for each different time slot. Finally we are going to visualize this data, but for the whole city and for each neigborhood.

# %% [markdown]
# We import the function, defined in another files, that we will need for our analysis.

# %%
import matplotlib.pyplot
import RQ2_functions

# %% [markdown]
# We build a dictonary contaning as keys the name of the boroughs and as values a list of the IDs associated, as seen in the reference file.

# %%
boroughs = RQ2_functions.boroughsIdentifyer()

# %% [markdown]
# The next function we are going to call will give as output a dictonary and a data frame. They will contain how many trip there are for each time slot. As time slots we decided to use:
# -  From 6AM to 10AM: People going to work
# -  From 10AM to 12AM: Workin hours
# -  From 12AM to 15PM: Lunch period
# -  From 15PM to 17PM: Working hours
# -  From 17PM to 22PM: Dinning period
# -  From 22PM to 6AM: Night
#
# The first one has the total trip for time slot for the whole city, the second one has them divided by borough. We count the trip as the number of taxing picking up a passenger in Manhattan.

# %%
time, time_borough = RQ2_functions.time_slotter(boroughs)

# %% [markdown]
# We shall first of all print them as simple tables, to give a look at them.

# %%
for item in time.keys():
     print(item.rjust(5), str(time[item]).rjust(20))
print(time_borough)
# Out:
#  6-10              9632329
# 10-12              5362186
# 12-15              8617655
# 15-17              5818869
# 17-22             15706105
#  22-6              8784878
#         EWR  Queens  Bronx  Manhattan  Staten Island  Brooklyn
# 6-10    609  538165  13428    8821911            134    116040
# 10-12   376  297097   4876    4937470             67     39428
# 12-15  1025  562206   7529    7836450             97     67269
# 15-17   652  419218   5239    5246959             69     47720
# 17-22   695  982309  10165   14273451            152    187171
# 22-6    497  558968  14572    7840196            296    225450

# %% [markdown]
# Now we shall do some effort to visualize the datas. We are going to plot them in two histograms with as x-axis the time slot and y-axis the number of trip.

# %%
matplotlib.rcParams['figure.figsize'] = (16,6)

matplotlib.pyplot.show(matplotlib.pyplot.bar(time.keys(), time.values(), color='yellow'))

matplotlib.pyplot.show(time_borough.loc[:,[borough for borough in boroughs.keys()]].iloc[:].plot(kind='bar', logy = True, figsize = (16,8)))

# %% [markdown]
# As we can see we decided to put the second graph in a logarithimc scale. The yellow cab company operates manly in Manhattan, so the amaunt of trips there is a lot larger. Putting the data in a loharithmic scale allow us to have comprensieble plot.

# %% [markdown]
# As we said the trip departing from Manhattan are largely more than the one from other places, therefore the graph for the whole city is more or less the same as the one for Manhattan.
#
# On the second graph we can see the different boroughs. It is particularly interesting to notice that the airport (EWR) does not follow the general tendecies. That is quite intuitive, but the back up this hypotesis quite nicly.
